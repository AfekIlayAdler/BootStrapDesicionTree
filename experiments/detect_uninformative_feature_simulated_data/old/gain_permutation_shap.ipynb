# %%
import numpy as np
import pandas as pd 
import shap
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm
from os import chdir 
from pathlib import Path
from os import getcwd
import pickle
chdir("C:\\Users\\afeki\\OneDrive\\Desktop\\code\\BootStrapDesicionTree\\")

# %load_ext autoreload
# %autoreload 2

# %%
from gradient_boosting_trees.gradient_boosting_regressor import CartGradientBoostingRegressor, \
    CartGradientBoostingRegressorKfold
from gradient_boosting_trees.gradient_boosting_abstract import GradientBoostingMachine
from Tree.node import Leaf

from sklearn.ensemble import GradientBoostingRegressor,GradientBoostingClassifier

from sklearn.model_selection import train_test_split

import xgboost as xgb
import pickle

from catboost import Pool, CatBoostRegressor

# %% [markdown]
# # Config

# %%
results = {}

# %% [markdown]
# # Create simulated data
# $$ y = a_1 \cdot x_1 + a_2 \cdot I(x_2 \in LEFT\_GROUP) + \sigma $$
#
# $$ x1 - N(0,1) $$

# %%
def compute_mse(model_name,model,X,y, transform_x = True, categorical_features = None):
    if transform_x:
        temp_x = X.copy()
        if model_name == 'xgboost':
            temp_x = xgb.DMatrix(temp_x)
        elif model_name == 'catboost':
            if categorical_features:
                temp_x = Pool(temp_x , cat_features = categorical_features)
            else:
                temp_x = Pool(temp_x)
        return np.mean(np.square(y - model.predict(temp_x)))
    return np.mean(np.square(y - model.predict(X)))
    
    
cat_features=[2]

def permutation_feature_importance(model_name,model,X,y, categorical_features = None):
    results = {}
    mse = compute_mse(model_name, model,X,y, categorical_features = categorical_features)
    for col in X.columns:
        temp_x = X.copy()
        temp_x[col] = np.random.permutation(temp_x[col])
        if model_name == 'xgboost':
            temp_x = xgb.DMatrix(temp_x)
        elif model_name == 'catboost':
            if categorical_features:
                temp_x = Pool(temp_x , cat_features = categorical_features)
            else:
                temp_x = Pool(temp_x)
        new_mse = compute_mse(model_name, model,temp_x,y, transform_x = False, categorical_features = categorical_features)
        results[col] = new_mse - mse
    results = pd.Series(results)
    return results/results.sum()

def get_x1_x2_shap_value(model, x, columns = None):
    if columns is None:
        columns = x.columns
    abs_shap_values = pd.DataFrame(shap.TreeExplainer(model, feature_perturbation = "tree_path_dependent").shap_values(x), columns = columns).apply(np.abs)
    shap_values = abs_shap_values.mean()/abs_shap_values.mean().sum()
    return shap_values['x1'] + shap_values['x2']

# %% [markdown]
# # OUR IMPLEMENTATION

# %%
from utils import all_experiments, create_x_y, n_experiments, get_fitted_model, create_one_hot_x_x_val, create_mean_imputing_x_x_val
from config import N_EXPERIMENTS,N_ROWS, SIGMA, A1, CATEGORY_COLUMN_NAME, Y_COL_NAME, MAX_DEPTH, LEARNING_RATE, N_ESTIMATORS,MODELS_DIR, A2, N_EXPERIMENTS, CATEGORIES
EXP_NAME = F"detect_uninformative_feature_{MAX_DEPTH}_nestimators_{N_ESTIMATORS}_learning_rate_{LEARNING_RATE}"

# %%
MODELS_DIR = Path(r"C:/Users/afeki/OneDrive/Desktop/code/BootStrapDesicionTree/experiments/detect_uninformative_feature_simulated_data/results/models/")
model_type= 'ours'
for exp_number, category_size in tqdm(all_experiments(), total=n_experiments):
    np.random.seed(exp_number)
    for predictor_name, predictor in {'Ffold': CartGradientBoostingRegressorKfold,'CartVanilla': CartGradientBoostingRegressor}.items():
        exp_name = F"{EXP_NAME}__{predictor_name}_exp_{exp_number}_category_size_{category_size}"
        model_path = MODELS_DIR / F"{exp_name}.pkl"
        X, y = create_x_y(category_size)
        X[Y_COL_NAME] = y
        model = get_fitted_model(model_path, predictor, X, Y_COL_NAME)
        fi_gain = pd.Series(model.compute_feature_importance(method='gain')).sort_index()
        fi_gain /= fi_gain.sum()
        fi_permutation = permutation_feature_importance(model_type,model,X,y)
        temp_results = np.array([fi_gain['x1'] + fi_gain['x2'],fi_permutation['x1'] + fi_permutation['x2']])
        key = (F"{model_type}_{predictor_name}", category_size)
        results.setdefault(key,np.zeros(len(temp_results)))
        results[key] += temp_results
# Out:
# 100%|██████████| 345/345 [37:54<00:00,  6.59s/it]

# %% [markdown]
# ## SKLEARN

# %%
pd.options.mode.chained_assignment = None 
model_type= 'sklearn'
for exp_number, category_size in tqdm(all_experiments(), total=n_experiments):
    np.random.seed(exp_number)
    for predictor_name, _ in {'one_hot': GradientBoostingRegressor,
                                      'mean_imputing': GradientBoostingRegressor}.items():
        X, y = create_x_y(category_size)
        if predictor_name == 'one_hot':
            X = pd.get_dummies(X)
        elif predictor_name == 'mean_imputing':
            df = X.copy()
            df[Y_COL_NAME] = y
            category_to_mean = df[[CATEGORY_COLUMN_NAME,Y_COL_NAME]].groupby(CATEGORY_COLUMN_NAME)[Y_COL_NAME].mean().to_dict()
            X[CATEGORY_COLUMN_NAME] = X[CATEGORY_COLUMN_NAME].map(category_to_mean)
            X[CATEGORY_COLUMN_NAME] = X[CATEGORY_COLUMN_NAME].astype('float')
        
        model = GradientBoostingRegressor(max_depth=MAX_DEPTH, n_estimators=N_ESTIMATORS, learning_rate=LEARNING_RATE)
        model.fit(X, y)
        fi_gain = pd.Series(model.feature_importances_, index = X.columns)
        fi_gain /= fi_gain.sum()
        fi_permutation = permutation_feature_importance(model_type,model,X,y)
        temp_results = np.array([fi_gain['x1'] +fi_gain['x2'],fi_permutation['x1'] + fi_permutation['x2'],get_x1_x2_shap_value(model, X) ])
        key = (F"{model_type}_{predictor_name}", category_size)
        results.setdefault(key,np.zeros(len(temp_results)))
        results[key] += temp_results
# Out:
#   0%|          | 0/345 [00:00<?, ?it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# The sklearn.ensemble.gradient_boosting module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   0%|          | 1/345 [00:00<02:18,  2.48it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   1%|          | 2/345 [00:00<02:20,  2.44it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   1%|          | 3/345 [00:01<02:22,  2.40it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   1%|          | 4/345 [00:01<02:23,  2.37it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   1%|▏         | 5/345 [00:02<02:25,  2.33it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   2%|▏         | 6/345 [00:02<02:33,  2.21it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   2%|▏         | 7/345 [00:03<02:48,  2.01it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   2%|▏         | 8/345 [00:03<02:57,  1.90it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   3%|▎         | 9/345 [00:04<03:08,  1.78it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   3%|▎         | 10/345 [00:05<03:21,  1.66it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   3%|▎         | 11/345 [00:06<03:42,  1.50it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   3%|▎         | 12/345 [00:06<03:57,  1.40it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   4%|▍         | 13/345 [00:07<04:09,  1.33it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   4%|▍         | 14/345 [00:08<04:27,  1.24it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#   4%|▍         | 15/345 [00:09<05:14,  1.05it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#
/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  86%|████████▌ | 296/345 [04:54<01:14,  1.52s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  86%|████████▌ | 297/345 [04:56<01:19,  1.66s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  86%|████████▋ | 298/345 [04:57<01:20,  1.71s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  87%|████████▋ | 299/345 [04:59<01:22,  1.79s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  87%|████████▋ | 300/345 [05:00<01:04,  1.43s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  87%|████████▋ | 301/345 [05:00<00:51,  1.16s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  88%|████████▊ | 302/345 [05:01<00:41,  1.04it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  88%|████████▊ | 303/345 [05:01<00:34,  1.22it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  88%|████████▊ | 304/345 [05:02<00:30,  1.35it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  88%|████████▊ | 305/345 [05:03<00:28,  1.41it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  89%|████████▊ | 306/345 [05:03<00:28,  1.37it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  89%|████████▉ | 307/345 [05:04<00:28,  1.32it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  89%|████████▉ | 308/345 [05:05<00:28,  1.31it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  90%|████████▉ | 309/345 [05:06<00:28,  1.27it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  90%|████████▉ | 310/345 [05:07<00:29,  1.19it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  90%|█████████ | 311/345 [05:08<00:30,  1.10it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  90%|█████████ | 312/345 [05:09<00:30,  1.07it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  91%|█████████ | 313/345 [05:10<00:31,  1.02it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  91%|█████████ | 314/345 [05:11<00:31,  1.01s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  91%|█████████▏| 315/345 [05:12<00:32,  1.07s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  92%|█████████▏| 316/345 [05:14<00:36,  1.25s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  92%|█████████▏| 317/345 [05:15<00:36,  1.30s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  92%|█████████▏| 318/345 [05:17<00:36,  1.35s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  92%|█████████▏| 319/345 [05:18<00:36,  1.40s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  93%|█████████▎| 320/345 [05:20<00:36,  1.47s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  93%|█████████▎| 321/345 [05:22<00:36,  1.54s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  93%|█████████▎| 322/345 [05:24<00:37,  1.65s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  94%|█████████▎| 323/345 [05:24<00:28,  1.31s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  94%|█████████▍| 324/345 [05:25<00:22,  1.06s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  94%|█████████▍| 325/345 [05:25<00:17,  1.12it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  94%|█████████▍| 326/345 [05:26<00:15,  1.25it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  95%|█████████▍| 327/345 [05:26<00:13,  1.36it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  95%|█████████▌| 328/345 [05:27<00:11,  1.44it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  95%|█████████▌| 329/345 [05:28<00:11,  1.42it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  96%|█████████▌| 330/345 [05:28<00:11,  1.31it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  96%|█████████▌| 331/345 [05:29<00:11,  1.22it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  96%|█████████▌| 332/345 [05:30<00:11,  1.15it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  97%|█████████▋| 333/345 [05:31<00:10,  1.11it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  97%|█████████▋| 334/345 [05:32<00:10,  1.07it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  97%|█████████▋| 335/345 [05:34<00:09,  1.01it/s]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  97%|█████████▋| 336/345 [05:35<00:09,  1.02s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  98%|█████████▊| 337/345 [05:36<00:08,  1.09s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  98%|█████████▊| 338/345 [05:37<00:07,  1.13s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  98%|█████████▊| 339/345 [05:38<00:07,  1.21s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  99%|█████████▊| 340/345 [05:40<00:06,  1.29s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  99%|█████████▉| 341/345 [05:41<00:05,  1.33s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  99%|█████████▉| 342/345 [05:43<00:04,  1.50s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
#  99%|█████████▉| 343/345 [05:45<00:03,  1.60s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 100%|█████████▉| 344/345 [05:47<00:01,  1.70s/it]Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# 100%|██████████| 345/345 [05:49<00:00,  1.01s/it]

# %% [markdown]
# ## XGBOOST

# %%
model_type= 'xgboost'
for exp_number, category_size in tqdm(all_experiments(), total=n_experiments):
    np.random.seed(exp_number)
    for predictor_name, _ in {'one_hot': GradientBoostingRegressor,
                                      'mean_imputing': GradientBoostingRegressor}.items():
        X, y = create_x_y(category_size)
        if predictor_name == 'one_hot':
            X = pd.get_dummies(X)
        elif predictor_name == 'mean_imputing':
            df = X.copy()
            df[Y_COL_NAME] = y
            category_to_mean = df[[CATEGORY_COLUMN_NAME,Y_COL_NAME]].groupby(CATEGORY_COLUMN_NAME)[Y_COL_NAME].mean().to_dict()
            X[CATEGORY_COLUMN_NAME] = X[CATEGORY_COLUMN_NAME].map(category_to_mean)
            X[CATEGORY_COLUMN_NAME] = X[CATEGORY_COLUMN_NAME].astype('float')
        
        dtrain = xgb.DMatrix(X, label=y)
        param = {'max_depth': MAX_DEPTH - 1, 'eta': LEARNING_RATE, 'objective': 'reg:squarederror'}
        bst = xgb.train(param, dtrain, N_ESTIMATORS)
        fi_gain = pd.Series(bst.get_score(importance_type='gain'))
        fi_gain /= fi_gain.sum()
        fi_permutation = permutation_feature_importance(model_type,bst,X,y)
        temp_results = np.array([fi_gain['x1'] +fi_gain['x2'],fi_permutation['x1'] + fi_permutation['x2'],get_x1_x2_shap_value(bst, X)])
        key = (F"{model_type}_{predictor_name}", category_size)
        results.setdefault(key,np.zeros(len(temp_results)))
        results[key] += temp_results
# Out:
# 100%|██████████| 345/345 [09:04<00:00,  1.58s/it]

# %% [markdown]
# ## Catboost

# %%
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
model_type= 'catboost'
for exp_number, category_size in tqdm(all_experiments(), total=n_experiments):
    np.random.seed(exp_number)
    for predictor_name in ["vanilla","mean_imputing"]:
        X, y = create_x_y(category_size)
        if predictor_name == 'mean_imputing':
            df = X.copy()
            df[Y_COL_NAME] = y
            category_to_mean = df[[CATEGORY_COLUMN_NAME,Y_COL_NAME]].groupby(CATEGORY_COLUMN_NAME)[Y_COL_NAME].mean().to_dict()
            X[CATEGORY_COLUMN_NAME] = X[CATEGORY_COLUMN_NAME].map(category_to_mean)
            X[CATEGORY_COLUMN_NAME] = X[CATEGORY_COLUMN_NAME].astype('float')
            train_pool = Pool(X, y)
        else:
            train_pool = Pool(X, y, cat_features=[2])
    
        model = CatBoostRegressor(iterations=N_ESTIMATORS, 
                                  depth=MAX_DEPTH, 
                                  learning_rate=LEARNING_RATE, 
                                  loss_function='RMSE',logging_level = 'Silent')
        model.fit(train_pool)
        fi_gain = pd.Series(model.feature_importances_, index = model.feature_names_)
        fi_gain /= fi_gain.sum()
        cat_feature = [2] if predictor_name == 'vanilla' else None
        fi_permutation = permutation_feature_importance(model_type,model,X,y,  categorical_features = cat_feature)
        temp_results = np.array([fi_gain['x1'] +fi_gain['x2'],fi_permutation['x1'] + fi_permutation['x2'], get_x1_x2_shap_value(model, train_pool, columns = X.columns)])
        key = (F"{model_type}_{predictor_name}", category_size)
        results.setdefault(key,np.zeros(len(temp_results)))
        results[key] += temp_results
# Out:
# 100%|██████████| 345/345 [02:11<00:00,  2.62it/s]

# %%
for key in results.keys():
    results[key] = results[key]/N_EXPERIMENTS
    
with open('experiments/detect_uninformative_feature_simulated_data/detect_uninformative_feature_results.pkl', 'wb') as output:
    pickle.dump(results, output, pickle.HIGHEST_PROTOCOL)
